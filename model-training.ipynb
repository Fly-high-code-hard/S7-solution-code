# %%
import pandas as pd
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
import xgboost as xgb
import pickle
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import optuna

pd.set_option("display.max_columns", 500)

# %%
# !ls -GFlash ../input/flight-delay-dataset-20182022/ | grep parquet
# Out:
# 216M -rw-r--r-- 1 nobody 216M Mar 28 15:05 Combined_Flights_2018.parquet
# 295M -rw-r--r-- 1 nobody 295M Mar 28 15:06 Combined_Flights_2019.parquet
# 175M -rw-r--r-- 1 nobody 175M Mar 28 15:05 Combined_Flights_2020.parquet
# 232M -rw-r--r-- 1 nobody 232M Mar 28 15:05 Combined_Flights_2021.parquet
# 143M -rw-r--r-- 1 nobody 143M Mar 28 15:05 Combined_Flights_2022.parquet

# %%
# !ls -GFlash ../input/flight-delay-dataset-20182022/ | grep csv
# Out:
#  40K -rw-r--r-- 1 nobody  39K Mar 28 15:04 Airlines.csv
# 1.9G -rw-r--r-- 1 nobody 1.9G Mar 28 15:07 Combined_Flights_2018.csv
# 2.7G -rw-r--r-- 1 nobody 2.7G Mar 28 15:08 Combined_Flights_2019.csv
# 1.7G -rw-r--r-- 1 nobody 1.7G Mar 28 15:07 Combined_Flights_2020.csv
# 2.1G -rw-r--r-- 1 nobody 2.1G Mar 28 15:07 Combined_Flights_2021.csv
# 1.4G -rw-r--r-- 1 nobody 1.4G Mar 28 15:07 Combined_Flights_2022.csv

# %%
print(xgb.__version__)  # Должна быть версия ≥1.5.0
print(xgb.build_info()["USE_CUDA"])  # Должно быть 'ON'
# Out:
# 1.6.2
# True

# %% [markdown]
# # Read in and Format Data

# %%
def get_time_category(deptime):
    # Преобразуем время в строку и добавляем ведущий ноль, если необходимо
    time_str = f"{int(deptime):04}"
    hours = int(time_str[:2])
    minutes = int(time_str[2:])
    
    if 6 <= hours < 12:
        return "Morning"
    elif 12 <= hours < 18:
        return "Day"
    elif 18 <= hours < 24:
        return "Evening"
    else:
        return "Night"

def target_encode(train_df, valid_df, test_df, column, target):
    # Вычисляем среднее значение целевой переменной для каждой категории в обучающей выборке
    mean_target = train_df.groupby(column)[target].mean()
    
    # Применяем кодирование к обучающей и тестовой выборкам
    train_df[column] = train_df[column].map(mean_target)
    test_df[column] = test_df[column].map(mean_target)
    valid_df[column] = valid_df[column].map(mean_target)
    
    # Заполняем пропуски (если есть категории, которые не встречались в обучающей выборке)
    train_df[column].fillna(train_df[target].mean(), inplace=True)
    test_df[column].fillna(train_df[target].mean(), inplace=True)
    valid_df[column].fillna(train_df[target].mean(), inplace=True)
    
    return train_df, valid_df, test_df, 

# Plot the confusion matrix for the test set
def plot_confusion_matrix(y_true, y_pred, title='Confusion Matrix'):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# %%
parquet_files = glob("../input/flight-delay-dataset-20182022/*.parquet")

# %%
column_subset = ["Flight_Number_Marketing_Airline", 'Month', 'DayOfWeek', 'DayofMonth', 'DOT_ID_Operating_Airline','Distance',
          'DistanceGroup', 'DestAirportSeqID','CRSDepTime', 'IATA_Code_Operating_Airline',
          'Airline', 'OriginAirportID', 'DestCityName', 'DestAirportID', 'Diverted', 'Cancelled',
          'IATA_Code_Marketing_Airline', 'DepDelayMinutes']

dfs = []
for f in parquet_files:
    dfs.append(pd.read_parquet(f, columns=column_subset))
df = pd.concat(dfs).reset_index(drop=True)

# %%
df = df[df['Cancelled'] == False]

# %%
df = df[df['CRSDepTime'].isna() == False]

df['daytime'] = df['CRSDepTime'].apply(get_time_category)

cat_cols = ['DOT_ID_Operating_Airline', 'Airline', 'OriginAirportID','DistanceGroup', 'IATA_Code_Operating_Airline',
                'DestCityName', 'DestAirportID','IATA_Code_Marketing_Airline', 'daytime']

for c in df.columns:
    print(df[c].isna().value_counts(), end='\n\n')
# Out:
# False    28416515
# Name: Flight_Number_Marketing_Airline, dtype: int64
#
# False    28416515
# Name: Month, dtype: int64
#
# False    28416515
# Name: DayOfWeek, dtype: int64
#
# False    28416515
# Name: DayofMonth, dtype: int64
#
# False    28416515
# Name: DOT_ID_Operating_Airline, dtype: int64
#
# False    28416515
# Name: Distance, dtype: int64
#
# False    28416515
# Name: DistanceGroup, dtype: int64
#
# False    28416515
# Name: DestAirportSeqID, dtype: int64
#
# False    28416515
# Name: CRSDepTime, dtype: int64
#
# False    28416515
# Name: IATA_Code_Operating_Airline, dtype: int64
#
# False    28416515
# Name: Airline, dtype: int64
#
# False    28416515
# Name: OriginAirportID, dtype: int64
#
# False    28416515
# Name: DestCityName, dtype: int64
#
# False    28416515
# Name: DestAirportID, dtype: int64
#
# False    28416515
# Name: Diverted, dtype: int64
#
# False    28416515
# Name: Cancelled, dtype: int64
#
# False    28416515
# Name: IATA_Code_Marketing_Airline, dtype: int64
#
# False    28415402
# True         1113
# Name: DepDelayMinutes, dtype: int64
#
# False    28416515
# Name: daytime, dtype: int64

# %% [markdown]
# **Dropping samples with Nan values.**

# %%
df.dropna(how='any', inplace=True)

# %%
df.drop('Cancelled', axis=1, inplace=True)

# %% [markdown]
# **Matching each sample to the delay group.**

# %%
df["DelayGroup"] = None

df.loc[df["DepDelayMinutes"] == 0, "DelayGroup"] = "OnTime_Early"

df.loc[
    (df["DepDelayMinutes"] > 0) & (df["DepDelayMinutes"] <= 120), "DelayGroup"
] = "Small_Delay"

df.loc[
    (df["DepDelayMinutes"] > 120) & (df["DepDelayMinutes"] <= 240), "DelayGroup"
] = "Medium_Delay"

df.loc[
(df["DepDelayMinutes"] > 240) & (df["DepDelayMinutes"] <= 480), "DelayGroup"] = "Large_Delay"

df.loc[df["DepDelayMinutes"] > 480, "DelayGroup"] = "Very_Large_Delay"

# %% [markdown]
# **Lets encode target variable**

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['DelayGroup'] = encoder.fit_transform(df['DelayGroup'])

# %%
print("Categories:", encoder.classes_)
print("Matching:", dict(zip(encoder.classes_, range(len(encoder.classes_)))))
# Out:
# Categories: ['Large_Delay' 'Medium_Delay' 'OnTime_Early' 'Small_Delay'
#  'Very_Large_Delay']
# Matching: {'Large_Delay': 0, 'Medium_Delay': 1, 'OnTime_Early': 2, 'Small_Delay': 3, 'Very_Large_Delay': 4}

# %%
df['DelayGroup'].value_counts()
# Out:
# 2    19240509
# 3     8518144
# 1      495912
# 0      122096
# 4       38741
# Name: DelayGroup, dtype: int64

# %%
df.to_parquet('data.parquet', engine='pyarrow')

# %%
X = df[['Month', 'DayOfWeek', 'DayofMonth', 'DOT_ID_Operating_Airline', 'Distance',
          'DistanceGroup', 'DestAirportSeqID', 'daytime', 'DepDelayMinutes',
          'Airline', 'OriginAirportID', 'DestCityName', 'DestAirportID', 'Diverted',
          'IATA_Code_Operating_Airline', 'IATA_Code_Marketing_Airline']]
y = df['DelayGroup']

# %% [markdown]
# **Split data on train, validation and test sets.**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=42)

# %% [markdown]
# **Using target encoder to encode categorical features.**

# %%
X_train_enc, X_valid_enc, X_test_enc = X_train, X_valid, X_test

for col in cat_cols:
    X_train_enc, X_valid_enc, X_test_enc = target_encode(X_train, X_valid, X_test, col, 'DepDelayMinutes')

X_train_enc.drop('DepDelayMinutes', axis=1, inplace=True)
X_valid_enc.drop('DepDelayMinutes', axis=1, inplace=True)
X_test_enc.drop('DepDelayMinutes', axis=1, inplace=True)

# %%
from sklearn.model_selection import cross_val_score

def objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate',0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.8, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'tree_method': 'gpu_hist',  # Использование GPU
        'gpu_id': 0,
        'eval_metric': 'mlogloss',
        'predictor': 'gpu_predictor',
        'random_state': 42
    }
    
    model = XGBClassifier(**params)
    score = cross_val_score(model, X_train_enc, y_train, cv=3, scoring='balanced_accuracy').mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=10)

print("Лучшие параметры:", study.best_params)

# %%
# Evaluate the model on the validation set
model = XGBClassifier(**{'max_depth': 9, 
                        'learning_rate': 0.19195495860894735, 
                        'subsample': 0.8730256621938772, 
                        'colsample_bytree': 0.6016748506491769, 
                        'n_estimators': 949,
                        'tree_method': 'gpu_hist',
                        'gpu_id': 0,
                        'eval_metric': 'mlogloss',
                        'predictor': 'gpu_predictor',
                        'random_state': 42})

model.fit(X_train_enc, y_train, eval_set=[(X_valid_enc, y_valid)])
# Out:
# [0]	validation_0-mlogloss:1.40009
# [1]	validation_0-mlogloss:1.25551
# [2]	validation_0-mlogloss:1.14849
# [3]	validation_0-mlogloss:1.06548
# [4]	validation_0-mlogloss:1.00116
# [5]	validation_0-mlogloss:0.94865
# [6]	validation_0-mlogloss:0.90639
# [7]	validation_0-mlogloss:0.87247
# [8]	validation_0-mlogloss:0.84447
# [9]	validation_0-mlogloss:0.81982
# [10]	validation_0-mlogloss:0.80029
# [11]	validation_0-mlogloss:0.78298
# [12]	validation_0-mlogloss:0.76896
# [13]	validation_0-mlogloss:0.75683
# [14]	validation_0-mlogloss:0.74601
# [15]	validation_0-mlogloss:0.73690
# [16]	validation_0-mlogloss:0.72911
# [17]	validation_0-mlogloss:0.72238
# [18]	validation_0-mlogloss:0.71653
# [19]	validation_0-mlogloss:0.71157
# [20]	validation_0-mlogloss:0.70721
# [21]	validation_0-mlogloss:0.70342
# [22]	validation_0-mlogloss:0.70001
# [23]	validation_0-mlogloss:0.69651
# [24]	validation_0-mlogloss:0.69398
# [25]	validation_0-mlogloss:0.69105
# [26]	validation_0-mlogloss:0.68890
# [27]	validation_0-mlogloss:0.68714
# [28]	validation_0-mlogloss:0.68553
# [29]	validation_0-mlogloss:0.68416
# [30]	validation_0-mlogloss:0.68287
# [31]	validation_0-mlogloss:0.68176
# [32]	validation_0-mlogloss:0.68025
# [33]	validation_0-mlogloss:0.67905
# [34]	validation_0-mlogloss:0.67828
# [35]	validation_0-mlogloss:0.67754
# [36]	validation_0-mlogloss:0.67697
# [37]	validation_0-mlogloss:0.67637
# [38]	validation_0-mlogloss:0.67585
# [39]	validation_0-mlogloss:0.67538
# [40]	validation_0-mlogloss:0.67491
# [41]	validation_0-mlogloss:0.67442
# [42]	validation_0-mlogloss:0.67406
# [43]	validation_0-mlogloss:0.67363
# [44]	validation_0-mlogloss:0.67334
# [45]	validation_0-mlogloss:0.67301
# [46]	validation_0-mlogloss:0.67276
# [47]	validation_0-mlogloss:0.67257
# [48]	validation_0-mlogloss:0.67211
# [49]	validation_0-mlogloss:0.67190
# [50]	validation_0-mlogloss:0.67170
# [51]	validation_0-mlogloss:0.67149
# [52]	validation_0-mlogloss:0.67130
# [53]	validation_0-mlogloss:0.67115
# [54]	validation_0-mlogloss:0.67069
# [55]	validation_0-mlogloss:0.67057
# [56]	validation_0-mlogloss:0.67044
# [57]	validation_0-mlogloss:0.67027
# [58]	validation_0-mlogloss:0.67006
# [59]	validation_0-mlogloss:0.66987
# [60]	validation_0-mlogloss:0.66959
# [61]	validation_0-mlogloss:0.66948
# [62]	validation_0-mlogloss:0.66938
# [63]	validation_0-mlogloss:0.66924
# [64]	validation_0-mlogloss:0.66908
# [65]	validation_0-mlogloss:0.66898
# [66]	validation_0-mlogloss:0.66835
# [67]	validation_0-mlogloss:0.66810
# [68]	validation_0-mlogloss:0.66803
# [69]	validation_0-mlogloss:0.66785
# [70]	validation_0-mlogloss:0.66779
# [71]	validation_0-mlogloss:0.66771
# [72]	validation_0-mlogloss:0.66767
# [73]	validation_0-mlogloss:0.66758
# [74]	validation_0-mlogloss:0.66754
# [75]	validation_0-mlogloss:0.66746
# [76]	validation_0-mlogloss:0.66739
# [77]	validation_0-mlogloss:0.66728
# [78]	validation_0-mlogloss:0.66719
# [79]	validation_0-mlogloss:0.66712
# [80]	validation_0-mlogloss:0.66703
# [81]	validation_0-mlogloss:0.66698
# [82]	validation_0-mlogloss:0.66693
# [83]	validation_0-mlogloss:0.66689
# [84]	validation_0-mlogloss:0.66670
# [85]	validation_0-mlogloss:0.66662
# [86]	validation_0-mlogloss:0.66654
# [87]	validation_0-mlogloss:0.66649
# [88]	validation_0-mlogloss:0.66639
# [89]	validation_0-mlogloss:0.66629
# [90]	validation_0-mlogloss:0.66624
# [91]	validation_0-mlogloss:0.66613
# [92]	validation_0-mlogloss:0.66607
# [93]	validation_0-mlogloss:0.66601
# [94]	validation_0-mlogloss:0.66598
# [95]	validation_0-mlogloss:0.66593
# [96]	validation_0-mlogloss:0.66590
# [97]	validation_0-mlogloss:0.66545
# [98]	validation_0-mlogloss:0.66537
# [99]	validation_0-mlogloss:0.66530
# [100]	validation_0-mlogloss:0.66521
# [101]	validation_0-mlogloss:0.66513
# [102]	validation_0-mlogloss:0.66504
# [103]	validation_0-mlogloss:0.66500
# [104]	validation_0-mlogloss:0.66441
# [105]	validation_0-mlogloss:0.66436
# [106]	validation_0-mlogloss:0.66405
# [107]	validation_0-mlogloss:0.66398
# [108]	validation_0-mlogloss:0.66394
# [109]	validation_0-mlogloss:0.66383
# [110]	validation_0-mlogloss:0.66375
# [111]	validation_0-mlogloss:0.66370
# [112]	validation_0-mlogloss:0.66367
# [113]	validation_0-mlogloss:0.66362
# [114]	validation_0-mlogloss:0.66358
# [115]	validation_0-mlogloss:0.66350
# [116]	validation_0-mlogloss:0.66346
# [117]	validation_0-mlogloss:0.66342
# [118]	validation_0-mlogloss:0.66336
# [119]	validation_0-mlogloss:0.66320
# [120]	validation_0-mlogloss:0.66316
# [121]	validation_0-mlogloss:0.66312
# [122]	validation_0-mlogloss:0.66308
# [123]	validation_0-mlogloss:0.66305
# [124]	validation_0-mlogloss:0.66301
# [125]	validation_0-mlogloss:0.66300
# [126]	validation_0-mlogloss:0.66296
# [127]	validation_0-mlogloss:0.66276
# [128]	validation_0-mlogloss:0.66273
# [129]	validation_0-mlogloss:0.66269
# [130]	validation_0-mlogloss:0.66266
# [131]	validation_0-mlogloss:0.66261
# [132]	validation_0-mlogloss:0.66258
# [133]	validation_0-mlogloss:0.66252
# [134]	validation_0-mlogloss:0.66247
# [135]	validation_0-mlogloss:0.66241
# [136]	validation_0-mlogloss:0.66233
# [137]	validation_0-mlogloss:0.66230
# [138]	validation_0-mlogloss:0.66226
# [139]	validation_0-mlogloss:0.66222
# [140]	validation_0-mlogloss:0.66204
# [141]	validation_0-mlogloss:0.66198
# [142]	validation_0-mlogloss:0.66170
# [143]	validation_0-mlogloss:0.66162
# [144]	validation_0-mlogloss:0.66158
# [145]	validation_0-mlogloss:0.66153
# [146]	validation_0-mlogloss:0.66147
# [147]	validation_0-mlogloss:0.66138
# [148]	validation_0-mlogloss:0.66118
# [149]	validation_0-mlogloss:0.66115
# [150]	validation_0-mlogloss:0.66114
# [151]	validation_0-mlogloss:0.66105
# [152]	validation_0-mlogloss:0.66102
# [153]	validation_0-mlogloss:0.66099
# [154]	validation_0-mlogloss:0.66093
# [155]	validation_0-mlogloss:0.66091
# [156]	validation_0-mlogloss:0.66083
# [157]	validation_0-mlogloss:0.66077
# [158]	validation_0-mlogloss:0.66075
# [159]	validation_0-mlogloss:0.66072
# [160]	validation_0-mlogloss:0.66069
# [161]	validation_0-mlogloss:0.66066
# [162]	validation_0-mlogloss:0.66059
# [163]	validation_0-mlogloss:0.66056
# [164]	validation_0-mlogloss:0.66054
# [165]	validation_0-mlogloss:0.66052
# [166]	validation_0-mlogloss:0.66049
# [167]	validation_0-mlogloss:0.66046
# [168]	validation_0-mlogloss:0.66044
# [169]	validation_0-mlogloss:0.66042
# [170]	validation_0-mlogloss:0.66041
# [171]	validation_0-mlogloss:0.66035
# [172]	validation_0-mlogloss:0.65983
# [173]	validation_0-mlogloss:0.65980
# [174]	validation_0-mlogloss:0.65977
# [175]	validation_0-mlogloss:0.65975
# [176]	validation_0-mlogloss:0.65951
# [177]	validation_0-mlogloss:0.65947
# [178]	validation_0-mlogloss:0.65944
# [179]	validation_0-mlogloss:0.65942
# [180]	validation_0-mlogloss:0.65938
# [181]	validation_0-mlogloss:0.65932
# [182]	validation_0-mlogloss:0.65929
# [183]	validation_0-mlogloss:0.65924
# [184]	validation_0-mlogloss:0.65921
# [185]	validation_0-mlogloss:0.65911
# [186]	validation_0-mlogloss:0.65907
# [187]	validation_0-mlogloss:0.65893
# [188]	validation_0-mlogloss:0.65890
# [189]	validation_0-mlogloss:0.65887
# [190]	validation_0-mlogloss:0.65886
# [191]	validation_0-mlogloss:0.65884
# [192]	validation_0-mlogloss:0.65882
# [193]	validation_0-mlogloss:0.65870
# [194]	validation_0-mlogloss:0.65855
# [195]	validation_0-mlogloss:0.65854
# [196]	validation_0-mlogloss:0.65853
# [197]	validation_0-mlogloss:0.65849
# [198]	validation_0-mlogloss:0.65847
# [199]	validation_0-mlogloss:0.65843
# [200]	validation_0-mlogloss:0.65840
# [201]	validation_0-mlogloss:0.65834
# [202]	validation_0-mlogloss:0.65833
# [203]	validation_0-mlogloss:0.65831
# [204]	validation_0-mlogloss:0.65829
# [205]	validation_0-mlogloss:0.65827
# [206]	validation_0-mlogloss:0.65806
# [207]	validation_0-mlogloss:0.65805
# [208]	validation_0-mlogloss:0.65800
# [209]	validation_0-mlogloss:0.65799
# [210]	validation_0-mlogloss:0.65797
# [211]	validation_0-mlogloss:0.65795
# [212]	validation_0-mlogloss:0.65793
# [213]	validation_0-mlogloss:0.65791
# [214]	validation_0-mlogloss:0.65787
# [215]	validation_0-mlogloss:0.65784
# [216]	validation_0-mlogloss:0.65781
# [217]	validation_0-mlogloss:0.65780
# [218]	validation_0-mlogloss:0.65777
# [219]	validation_0-mlogloss:0.65775
# [220]	validation_0-mlogloss:0.65759
# [221]	validation_0-mlogloss:0.65731
# [222]	validation_0-mlogloss:0.65720
# [223]	validation_0-mlogloss:0.65718
# [224]	validation_0-mlogloss:0.65715
# [225]	validation_0-mlogloss:0.65712
# [226]	validation_0-mlogloss:0.65710
# [227]	validation_0-mlogloss:0.65708
# [228]	validation_0-mlogloss:0.65707
# [229]	validation_0-mlogloss:0.65704
# [230]	validation_0-mlogloss:0.65702
# [231]	validation_0-mlogloss:0.65701
# [232]	validation_0-mlogloss:0.65698
# [233]	validation_0-mlogloss:0.65689
# [234]	validation_0-mlogloss:0.65686
# [235]	validation_0-mlogloss:0.65664
# [236]	validation_0-mlogloss:0.65661
# [237]	validation_0-mlogloss:0.65660
# [238]	validation_0-mlogloss:0.65658
# [239]	validation_0-mlogloss:0.65657
# [240]	validation_0-mlogloss:0.65656
# [241]	validation_0-mlogloss:0.65653
# [242]	validation_0-mlogloss:0.65653
# [243]	validation_0-mlogloss:0.65639
# [244]	validation_0-mlogloss:0.65638
# [245]	validation_0-mlogloss:0.65626
# [246]	validation_0-mlogloss:0.65625
# [247]	validation_0-mlogloss:0.65624
# [248]	validation_0-mlogloss:0.65621
# [249]	validation_0-mlogloss:0.65619
# [250]	validation_0-mlogloss:0.65616
# [251]	validation_0-mlogloss:0.65615
# [252]	validation_0-mlogloss:0.65609
# [253]	validation_0-mlogloss:0.65608
# [254]	validation_0-mlogloss:0.65598
# [255]	validation_0-mlogloss:0.65596
# [256]	validation_0-mlogloss:0.65595
# [257]	validation_0-mlogloss:0.65593
# [258]	validation_0-mlogloss:0.65587
# [259]	validation_0-mlogloss:0.65583
# [260]	validation_0-mlogloss:0.65569
# [261]	validation_0-mlogloss:0.65567
# [262]	validation_0-mlogloss:0.65562
# [263]	validation_0-mlogloss:0.65561
# [264]	validation_0-mlogloss:0.65554
# [265]	validation_0-mlogloss:0.65554
# [266]	validation_0-mlogloss:0.65553
# [267]	validation_0-mlogloss:0.65551
# [268]	validation_0-mlogloss:0.65548
# [269]	validation_0-mlogloss:0.65545
# [270]	validation_0-mlogloss:0.65544
# [271]	validation_0-mlogloss:0.65543
# [272]	validation_0-mlogloss:0.65541
# [273]	validation_0-mlogloss:0.65540
# [274]	validation_0-mlogloss:0.65540
# [275]	validation_0-mlogloss:0.65538
# [276]	validation_0-mlogloss:0.65536
# [277]	validation_0-mlogloss:0.65536
# [278]	validation_0-mlogloss:0.65513
# [279]	validation_0-mlogloss:0.65512
# [280]	validation_0-mlogloss:0.65511
# [281]	validation_0-mlogloss:0.65501
# [282]	validation_0-mlogloss:0.65499
# [283]	validation_0-mlogloss:0.65498
# [284]	validation_0-mlogloss:0.65495
# [285]	validation_0-mlogloss:0.65490
# [286]	validation_0-mlogloss:0.65489
# [287]	validation_0-mlogloss:0.65485
# [288]	validation_0-mlogloss:0.65483
# [289]	validation_0-mlogloss:0.65479
# [290]	validation_0-mlogloss:0.65477
# [291]	validation_0-mlogloss:0.65473
# [292]	validation_0-mlogloss:0.65470
# [293]	validation_0-mlogloss:0.65469
# [294]	validation_0-mlogloss:0.65451
# [295]	validation_0-mlogloss:0.65447
# [296]	validation_0-mlogloss:0.65437
# [297]	validation_0-mlogloss:0.65436
# [298]	validation_0-mlogloss:0.65435
# [299]	validation_0-mlogloss:0.65434
# [300]	validation_0-mlogloss:0.65433
# [301]	validation_0-mlogloss:0.65433
# [302]	validation_0-mlogloss:0.65431
# [303]	validation_0-mlogloss:0.65430
# [304]	validation_0-mlogloss:0.65430
# [305]	validation_0-mlogloss:0.65429
# [306]	validation_0-mlogloss:0.65428
# [307]	validation_0-mlogloss:0.65427
# [308]	validation_0-mlogloss:0.65423
# [309]	validation_0-mlogloss:0.65421
# [310]	validation_0-mlogloss:0.65420
# [311]	validation_0-mlogloss:0.65419
# [312]	validation_0-mlogloss:0.65418
# [313]	validation_0-mlogloss:0.65417
# [314]	validation_0-mlogloss:0.65416
# [315]	validation_0-mlogloss:0.65416
# [316]	validation_0-mlogloss:0.65410
# [317]	validation_0-mlogloss:0.65406
# [318]	validation_0-mlogloss:0.65402
# [319]	validation_0-mlogloss:0.65393
# [320]	validation_0-mlogloss:0.65392
# [321]	validation_0-mlogloss:0.65388
# [322]	validation_0-mlogloss:0.65378
# [323]	validation_0-mlogloss:0.65377
# [324]	validation_0-mlogloss:0.65376
# [325]	validation_0-mlogloss:0.65376
# [326]	validation_0-mlogloss:0.65374
# [327]	validation_0-mlogloss:0.65373
# [328]	validation_0-mlogloss:0.65372
# [329]	validation_0-mlogloss:0.65371
# [330]	validation_0-mlogloss:0.65368
# [331]	validation_0-mlogloss:0.65367
# [332]	validation_0-mlogloss:0.65365
# [333]	validation_0-mlogloss:0.65365
# [334]	validation_0-mlogloss:0.65347
# [335]	validation_0-mlogloss:0.65346
# [336]	validation_0-mlogloss:0.65343
# [337]	validation_0-mlogloss:0.65340
# [338]	validation_0-mlogloss:0.65337
# [339]	validation_0-mlogloss:0.65336
# [340]	validation_0-mlogloss:0.65335
# [341]	validation_0-mlogloss:0.65335
# [342]	validation_0-mlogloss:0.65334
# [343]	validation_0-mlogloss:0.65332
# [344]	validation_0-mlogloss:0.65331
# [345]	validation_0-mlogloss:0.65312
# [346]	validation_0-mlogloss:0.65311
# [347]	validation_0-mlogloss:0.65303
# [348]	validation_0-mlogloss:0.65302
# [349]	validation_0-mlogloss:0.65301
# [350]	validation_0-mlogloss:0.65300
# [351]	validation_0-mlogloss:0.65300
# [352]	validation_0-mlogloss:0.65285
# [353]	validation_0-mlogloss:0.65285
# [354]	validation_0-mlogloss:0.65283
# [355]	validation_0-mlogloss:0.65282
# [356]	validation_0-mlogloss:0.65280
# [357]	validation_0-mlogloss:0.65279
# [358]	validation_0-mlogloss:0.65277
# [359]	validation_0-mlogloss:0.65277
# [360]	validation_0-mlogloss:0.65276
# [361]	validation_0-mlogloss:0.65276
# [362]	validation_0-mlogloss:0.65275
# [363]	validation_0-mlogloss:0.65273
# [364]	validation_0-mlogloss:0.65272
# [365]	validation_0-mlogloss:0.65267
# [366]	validation_0-mlogloss:0.65266
# [367]	validation_0-mlogloss:0.65266
# [368]	validation_0-mlogloss:0.65265
# [369]	validation_0-mlogloss:0.65265
# [370]	validation_0-mlogloss:0.65260
# [371]	validation_0-mlogloss:0.65257
# [372]	validation_0-mlogloss:0.65255
# [373]	validation_0-mlogloss:0.65253
# [374]	validation_0-mlogloss:0.65252
# [375]	validation_0-mlogloss:0.65243
# [376]	validation_0-mlogloss:0.65241
# [377]	validation_0-mlogloss:0.65240
# [378]	validation_0-mlogloss:0.65239
# [379]	validation_0-mlogloss:0.65238
# [380]	validation_0-mlogloss:0.65237
# [381]	validation_0-mlogloss:0.65236
# [382]	validation_0-mlogloss:0.65235
# [383]	validation_0-mlogloss:0.65234
# [384]	validation_0-mlogloss:0.65225
# [385]	validation_0-mlogloss:0.65223
# [386]	validation_0-mlogloss:0.65222
# [387]	validation_0-mlogloss:0.65221
# [388]	validation_0-mlogloss:0.65221
# [389]	validation_0-mlogloss:0.65217
# [390]	validation_0-mlogloss:0.65216
# [391]	validation_0-mlogloss:0.65213
# [392]	validation_0-mlogloss:0.65211
# [393]	validation_0-mlogloss:0.65211
# [394]	validation_0-mlogloss:0.65210
# [395]	validation_0-mlogloss:0.65209
# [396]	validation_0-mlogloss:0.65209
# [397]	validation_0-mlogloss:0.65198
# [398]	validation_0-mlogloss:0.65195
# [399]	validation_0-mlogloss:0.65195
# [400]	validation_0-mlogloss:0.65194
# [401]	validation_0-mlogloss:0.65193
# [402]	validation_0-mlogloss:0.65189
# [403]	validation_0-mlogloss:0.65175
# [404]	validation_0-mlogloss:0.65174
# [405]	validation_0-mlogloss:0.65173
# [406]	validation_0-mlogloss:0.65171
# [407]	validation_0-mlogloss:0.65170
# [408]	validation_0-mlogloss:0.65169
# [409]	validation_0-mlogloss:0.65169
# [410]	validation_0-mlogloss:0.65168
# [411]	validation_0-mlogloss:0.65167
# [412]	validation_0-mlogloss:0.65163
# [413]	validation_0-mlogloss:0.65158
# [414]	validation_0-mlogloss:0.65158
# [415]	validation_0-mlogloss:0.65148
# [416]	validation_0-mlogloss:0.65147
# [417]	validation_0-mlogloss:0.65144
# [418]	validation_0-mlogloss:0.65137
# [419]	validation_0-mlogloss:0.65113
# [420]	validation_0-mlogloss:0.65112
# [421]	validation_0-mlogloss:0.65112
# [422]	validation_0-mlogloss:0.65098
# [423]	validation_0-mlogloss:0.65089
# [424]	validation_0-mlogloss:0.65088
# [425]	validation_0-mlogloss:0.65087
# [426]	validation_0-mlogloss:0.65087
# [427]	validation_0-mlogloss:0.65086
# [428]	validation_0-mlogloss:0.65085
# [429]	validation_0-mlogloss:0.65085
# [430]	validation_0-mlogloss:0.65085
# [431]	validation_0-mlogloss:0.65084
# [432]	validation_0-mlogloss:0.65084
# [433]	validation_0-mlogloss:0.65083
# [434]	validation_0-mlogloss:0.65082
# [435]	validation_0-mlogloss:0.65082
# [436]	validation_0-mlogloss:0.65082
# [437]	validation_0-mlogloss:0.65081
# [438]	validation_0-mlogloss:0.65081
# [439]	validation_0-mlogloss:0.65080
# [440]	validation_0-mlogloss:0.65079
# [441]	validation_0-mlogloss:0.65079
# [442]	validation_0-mlogloss:0.65074
# [443]	validation_0-mlogloss:0.65063
# [444]	validation_0-mlogloss:0.65063
# [445]	validation_0-mlogloss:0.65062
# [446]	validation_0-mlogloss:0.65062
# [447]	validation_0-mlogloss:0.65062
# [448]	validation_0-mlogloss:0.65061
# [449]	validation_0-mlogloss:0.65057
# [450]	validation_0-mlogloss:0.65057
# [451]	validation_0-mlogloss:0.65057
# [452]	validation_0-mlogloss:0.65057
# [453]	validation_0-mlogloss:0.65056
# [454]	validation_0-mlogloss:0.65054
# [455]	validation_0-mlogloss:0.65051
# [456]	validation_0-mlogloss:0.65050
# [457]	validation_0-mlogloss:0.65048
# [458]	validation_0-mlogloss:0.65048
# [459]	validation_0-mlogloss:0.65047
# [460]	validation_0-mlogloss:0.65046
# [461]	validation_0-mlogloss:0.65045
# [462]	validation_0-mlogloss:0.65045
# [463]	validation_0-mlogloss:0.65041
# [464]	validation_0-mlogloss:0.65040
# [465]	validation_0-mlogloss:0.65039
# [466]	validation_0-mlogloss:0.65039
# [467]	validation_0-mlogloss:0.65037
# [468]	validation_0-mlogloss:0.65037
# [469]	validation_0-mlogloss:0.65036
# [470]	validation_0-mlogloss:0.65035
# [471]	validation_0-mlogloss:0.65035
# [472]	validation_0-mlogloss:0.65035
# [473]	validation_0-mlogloss:0.65035
# [474]	validation_0-mlogloss:0.65034
# [475]	validation_0-mlogloss:0.65034
# [476]	validation_0-mlogloss:0.65031
# [477]	validation_0-mlogloss:0.65030
# [478]	validation_0-mlogloss:0.65029
# [479]	validation_0-mlogloss:0.65028
# [480]	validation_0-mlogloss:0.65027
# [481]	validation_0-mlogloss:0.65026
# [482]	validation_0-mlogloss:0.65018
# [483]	validation_0-mlogloss:0.65018
# [484]	validation_0-mlogloss:0.65010
# [485]	validation_0-mlogloss:0.65010
# [486]	validation_0-mlogloss:0.65009
# [487]	validation_0-mlogloss:0.65009
# [488]	validation_0-mlogloss:0.65009
# [489]	validation_0-mlogloss:0.65009
# [490]	validation_0-mlogloss:0.65008
# [491]	validation_0-mlogloss:0.65006
# [492]	validation_0-mlogloss:0.65005
# [493]	validation_0-mlogloss:0.65004
# [494]	validation_0-mlogloss:0.65001
# [495]	validation_0-mlogloss:0.65000
# [496]	validation_0-mlogloss:0.65000
# [497]	validation_0-mlogloss:0.65000
# [498]	validation_0-mlogloss:0.64999
# [499]	validation_0-mlogloss:0.64999
# [500]	validation_0-mlogloss:0.64998
# [501]	validation_0-mlogloss:0.64997
# [502]	validation_0-mlogloss:0.64992
# [503]	validation_0-mlogloss:0.64992
# [504]	validation_0-mlogloss:0.64991
# [505]	validation_0-mlogloss:0.64990
# [506]	validation_0-mlogloss:0.64988
# [507]	validation_0-mlogloss:0.64988
# [508]	validation_0-mlogloss:0.64988
# [509]	validation_0-mlogloss:0.64988
# [510]	validation_0-mlogloss:0.64986
# [511]	validation_0-mlogloss:0.64980
# [512]	validation_0-mlogloss:0.64979
# [513]	validation_0-mlogloss:0.64979
# [514]	validation_0-mlogloss:0.64979
# [515]	validation_0-mlogloss:0.64977
# [516]	validation_0-mlogloss:0.64977
# [517]	validation_0-mlogloss:0.64976
# [518]	validation_0-mlogloss:0.64975
# [519]	validation_0-mlogloss:0.64975
# [520]	validation_0-mlogloss:0.64971
# [521]	validation_0-mlogloss:0.64969
# [522]	validation_0-mlogloss:0.64969
# [523]	validation_0-mlogloss:0.64969
# [524]	validation_0-mlogloss:0.64964
# [525]	validation_0-mlogloss:0.64964
# [526]	validation_0-mlogloss:0.64963
# [527]	validation_0-mlogloss:0.64960
# [528]	validation_0-mlogloss:0.64958
# [529]	validation_0-mlogloss:0.64956
# [530]	validation_0-mlogloss:0.64955
# [531]	validation_0-mlogloss:0.64955
# [532]	validation_0-mlogloss:0.64953
# [533]	validation_0-mlogloss:0.64953
# [534]	validation_0-mlogloss:0.64937
# [535]	validation_0-mlogloss:0.64937
# [536]	validation_0-mlogloss:0.64935
# [537]	validation_0-mlogloss:0.64934
# [538]	validation_0-mlogloss:0.64933
# [539]	validation_0-mlogloss:0.64932
# [540]	validation_0-mlogloss:0.64932
# [541]	validation_0-mlogloss:0.64932
# [542]	validation_0-mlogloss:0.64931
# [543]	validation_0-mlogloss:0.64931
# [544]	validation_0-mlogloss:0.64930
# [545]	validation_0-mlogloss:0.64927
# [546]	validation_0-mlogloss:0.64916
# [547]	validation_0-mlogloss:0.64916
# [548]	validation_0-mlogloss:0.64916
# [549]	validation_0-mlogloss:0.64916
# [550]	validation_0-mlogloss:0.64900
# [551]	validation_0-mlogloss:0.64899
# [552]	validation_0-mlogloss:0.64899
# [553]	validation_0-mlogloss:0.64898
# [554]	validation_0-mlogloss:0.64898
# [555]	validation_0-mlogloss:0.64897
# [556]	validation_0-mlogloss:0.64893
# [557]	validation_0-mlogloss:0.64892
# [558]	validation_0-mlogloss:0.64892
# [559]	validation_0-mlogloss:0.64892
# [560]	validation_0-mlogloss:0.64892
# [561]	validation_0-mlogloss:0.64890
# [562]	validation_0-mlogloss:0.64889
# [563]	validation_0-mlogloss:0.64888
# [564]	validation_0-mlogloss:0.64888
# [565]	validation_0-mlogloss:0.64887
# [566]	validation_0-mlogloss:0.64880
# [567]	validation_0-mlogloss:0.64880
# [568]	validation_0-mlogloss:0.64880
# [569]	validation_0-mlogloss:0.64879
# [570]	validation_0-mlogloss:0.64879
# [571]	validation_0-mlogloss:0.64878
# [572]	validation_0-mlogloss:0.64878
# [573]	validation_0-mlogloss:0.64877
# [574]	validation_0-mlogloss:0.64876
# [575]	validation_0-mlogloss:0.64877
# [576]	validation_0-mlogloss:0.64876
# [577]	validation_0-mlogloss:0.64876
# [578]	validation_0-mlogloss:0.64875
# [579]	validation_0-mlogloss:0.64872
# [580]	validation_0-mlogloss:0.64872
# [581]	validation_0-mlogloss:0.64871
# [582]	validation_0-mlogloss:0.64871
# [583]	validation_0-mlogloss:0.64870
# [584]	validation_0-mlogloss:0.64870
# [585]	validation_0-mlogloss:0.64868
# [586]	validation_0-mlogloss:0.64867
# [587]	validation_0-mlogloss:0.64867
# [588]	validation_0-mlogloss:0.64866
# [589]	validation_0-mlogloss:0.64865
# [590]	validation_0-mlogloss:0.64865
# [591]	validation_0-mlogloss:0.64864
# [592]	validation_0-mlogloss:0.64864
# [593]	validation_0-mlogloss:0.64862
# [594]	validation_0-mlogloss:0.64853
# [595]	validation_0-mlogloss:0.64853
# [596]	validation_0-mlogloss:0.64853
# [597]	validation_0-mlogloss:0.64847
# [598]	validation_0-mlogloss:0.64838
# [599]	validation_0-mlogloss:0.64836
# [600]	validation_0-mlogloss:0.64835
# [601]	validation_0-mlogloss:0.64833
# [602]	validation_0-mlogloss:0.64832
# [603]	validation_0-mlogloss:0.64828
# [604]	validation_0-mlogloss:0.64825
# [605]	validation_0-mlogloss:0.64825
# [606]	validation_0-mlogloss:0.64825
# [607]	validation_0-mlogloss:0.64824
# [608]	validation_0-mlogloss:0.64823
# [609]	validation_0-mlogloss:0.64821
# [610]	validation_0-mlogloss:0.64820
# [611]	validation_0-mlogloss:0.64818
# [612]	validation_0-mlogloss:0.64812
# [613]	validation_0-mlogloss:0.64812
# [614]	validation_0-mlogloss:0.64811
# [615]	validation_0-mlogloss:0.64811
# [616]	validation_0-mlogloss:0.64811
# [617]	validation_0-mlogloss:0.64806
# [618]	validation_0-mlogloss:0.64805
# [619]	validation_0-mlogloss:0.64805
# [620]	validation_0-mlogloss:0.64801
# [621]	validation_0-mlogloss:0.64800
# [622]	validation_0-mlogloss:0.64794
# [623]	validation_0-mlogloss:0.64793
# [624]	validation_0-mlogloss:0.64790
# [625]	validation_0-mlogloss:0.64789
# [626]	validation_0-mlogloss:0.64788
# [627]	validation_0-mlogloss:0.64788
# [628]	validation_0-mlogloss:0.64779
# [629]	validation_0-mlogloss:0.64779
# [630]	validation_0-mlogloss:0.64778
# [631]	validation_0-mlogloss:0.64773
# [632]	validation_0-mlogloss:0.64773
# [633]	validation_0-mlogloss:0.64773
# [634]	validation_0-mlogloss:0.64772
# [635]	validation_0-mlogloss:0.64772
# [636]	validation_0-mlogloss:0.64771
# [637]	validation_0-mlogloss:0.64770
# [638]	validation_0-mlogloss:0.64770
# [639]	validation_0-mlogloss:0.64768
# [640]	validation_0-mlogloss:0.64768
# [641]	validation_0-mlogloss:0.64765
# [642]	validation_0-mlogloss:0.64764
# [643]	validation_0-mlogloss:0.64763
# [644]	validation_0-mlogloss:0.64762
# [645]	validation_0-mlogloss:0.64761
# [646]	validation_0-mlogloss:0.64761
# [647]	validation_0-mlogloss:0.64761
# [648]	validation_0-mlogloss:0.64761
# [649]	validation_0-mlogloss:0.64760
# [650]	validation_0-mlogloss:0.64760
# [651]	validation_0-mlogloss:0.64758
# [652]	validation_0-mlogloss:0.64758
# [653]	validation_0-mlogloss:0.64758
# [654]	validation_0-mlogloss:0.64758
# [655]	validation_0-mlogloss:0.64758
# [656]	validation_0-mlogloss:0.64758
# [657]	validation_0-mlogloss:0.64758
# [658]	validation_0-mlogloss:0.64757
# [659]	validation_0-mlogloss:0.64753
# [660]	validation_0-mlogloss:0.64751
# [661]	validation_0-mlogloss:0.64751
# [662]	validation_0-mlogloss:0.64750
# [663]	validation_0-mlogloss:0.64750
# [664]	validation_0-mlogloss:0.64747
# [665]	validation_0-mlogloss:0.64747
# [666]	validation_0-mlogloss:0.64747
# [667]	validation_0-mlogloss:0.64747
# [668]	validation_0-mlogloss:0.64746
# [669]	validation_0-mlogloss:0.64746
# [670]	validation_0-mlogloss:0.64745
# [671]	validation_0-mlogloss:0.64745
# [672]	validation_0-mlogloss:0.64745
# [673]	validation_0-mlogloss:0.64737
# [674]	validation_0-mlogloss:0.64734
# [675]	validation_0-mlogloss:0.64727
# [676]	validation_0-mlogloss:0.64725
# [677]	validation_0-mlogloss:0.64726
# [678]	validation_0-mlogloss:0.64722
# [679]	validation_0-mlogloss:0.64722
# [680]	validation_0-mlogloss:0.64721
# [681]	validation_0-mlogloss:0.64719
# [682]	validation_0-mlogloss:0.64719
# [683]	validation_0-mlogloss:0.64719
# [684]	validation_0-mlogloss:0.64717
# [685]	validation_0-mlogloss:0.64716
# [686]	validation_0-mlogloss:0.64710
# [687]	validation_0-mlogloss:0.64709
# [688]	validation_0-mlogloss:0.64706
# [689]	validation_0-mlogloss:0.64706
# [690]	validation_0-mlogloss:0.64702
# [691]	validation_0-mlogloss:0.64700
# [692]	validation_0-mlogloss:0.64699
# [693]	validation_0-mlogloss:0.64698
# [694]	validation_0-mlogloss:0.64698
# [695]	validation_0-mlogloss:0.64698
# [696]	validation_0-mlogloss:0.64697
# [697]	validation_0-mlogloss:0.64695
# [698]	validation_0-mlogloss:0.64695
# [699]	validation_0-mlogloss:0.64693
# [700]	validation_0-mlogloss:0.64691
# [701]	validation_0-mlogloss:0.64691
# [702]	validation_0-mlogloss:0.64691
# [703]	validation_0-mlogloss:0.64687
# [704]	validation_0-mlogloss:0.64686
# [705]	validation_0-mlogloss:0.64686
# [706]	validation_0-mlogloss:0.64684
# [707]	validation_0-mlogloss:0.64683
# [708]	validation_0-mlogloss:0.64683
# [709]	validation_0-mlogloss:0.64682
# [710]	validation_0-mlogloss:0.64682
# [711]	validation_0-mlogloss:0.64682
# [712]	validation_0-mlogloss:0.64682
# [713]	validation_0-mlogloss:0.64682
# [714]	validation_0-mlogloss:0.64675
# [715]	validation_0-mlogloss:0.64672
# [716]	validation_0-mlogloss:0.64671
# [717]	validation_0-mlogloss:0.64670
# [718]	validation_0-mlogloss:0.64668
# [719]	validation_0-mlogloss:0.64667
# [720]	validation_0-mlogloss:0.64666
# [721]	validation_0-mlogloss:0.64666
# [722]	validation_0-mlogloss:0.64661
# [723]	validation_0-mlogloss:0.64660
# [724]	validation_0-mlogloss:0.64660
# [725]	validation_0-mlogloss:0.64659
# [726]	validation_0-mlogloss:0.64658
# [727]	validation_0-mlogloss:0.64657
# [728]	validation_0-mlogloss:0.64648
# [729]	validation_0-mlogloss:0.64648
# [730]	validation_0-mlogloss:0.64648
# [731]	validation_0-mlogloss:0.64648
# [732]	validation_0-mlogloss:0.64648
# [733]	validation_0-mlogloss:0.64647
# [734]	validation_0-mlogloss:0.64646
# [735]	validation_0-mlogloss:0.64646
# [736]	validation_0-mlogloss:0.64646
# [737]	validation_0-mlogloss:0.64646
# [738]	validation_0-mlogloss:0.64642
# [739]	validation_0-mlogloss:0.64640
# [740]	validation_0-mlogloss:0.64640
# [741]	validation_0-mlogloss:0.64640
# [742]	validation_0-mlogloss:0.64640
# [743]	validation_0-mlogloss:0.64638
# [744]	validation_0-mlogloss:0.64638
# [745]	validation_0-mlogloss:0.64638
# [746]	validation_0-mlogloss:0.64637
# [747]	validation_0-mlogloss:0.64636
# [748]	validation_0-mlogloss:0.64635
# [749]	validation_0-mlogloss:0.64635
# [750]	validation_0-mlogloss:0.64635
# [751]	validation_0-mlogloss:0.64634
# [752]	validation_0-mlogloss:0.64634
# [753]	validation_0-mlogloss:0.64630
# [754]	validation_0-mlogloss:0.64629
# [755]	validation_0-mlogloss:0.64629
# [756]	validation_0-mlogloss:0.64628
# [757]	validation_0-mlogloss:0.64626
# [758]	validation_0-mlogloss:0.64625
# [759]	validation_0-mlogloss:0.64625
# [760]	validation_0-mlogloss:0.64624
# [761]	validation_0-mlogloss:0.64623
# [762]	validation_0-mlogloss:0.64623
# [763]	validation_0-mlogloss:0.64623
# [764]	validation_0-mlogloss:0.64623
# [765]	validation_0-mlogloss:0.64622
# [766]	validation_0-mlogloss:0.64621
# [767]	validation_0-mlogloss:0.64617
# [768]	validation_0-mlogloss:0.64617
# [769]	validation_0-mlogloss:0.64612
# [770]	validation_0-mlogloss:0.64612
# [771]	validation_0-mlogloss:0.64611
# [772]	validation_0-mlogloss:0.64611
# [773]	validation_0-mlogloss:0.64600
# [774]	validation_0-mlogloss:0.64600
# [775]	validation_0-mlogloss:0.64600
# [776]	validation_0-mlogloss:0.64600
# [777]	validation_0-mlogloss:0.64600
# [778]	validation_0-mlogloss:0.64599
# [779]	validation_0-mlogloss:0.64599
# [780]	validation_0-mlogloss:0.64599
# [781]	validation_0-mlogloss:0.64599
# [782]	validation_0-mlogloss:0.64599
# [783]	validation_0-mlogloss:0.64599
# [784]	validation_0-mlogloss:0.64599
# [785]	validation_0-mlogloss:0.64599
# [786]	validation_0-mlogloss:0.64597
# [787]	validation_0-mlogloss:0.64597
# [788]	validation_0-mlogloss:0.64596
# [789]	validation_0-mlogloss:0.64596
# [790]	validation_0-mlogloss:0.64595
# [791]	validation_0-mlogloss:0.64595
# [792]	validation_0-mlogloss:0.64595
# [793]	validation_0-mlogloss:0.64594
# [794]	validation_0-mlogloss:0.64594
# [795]	validation_0-mlogloss:0.64594
# [796]	validation_0-mlogloss:0.64594
# [797]	validation_0-mlogloss:0.64594
# [798]	validation_0-mlogloss:0.64584
# [799]	validation_0-mlogloss:0.64583
# [800]	validation_0-mlogloss:0.64583
# [801]	validation_0-mlogloss:0.64583
# [802]	validation_0-mlogloss:0.64582
# [803]	validation_0-mlogloss:0.64582
# [804]	validation_0-mlogloss:0.64582
# [805]	validation_0-mlogloss:0.64580
# [806]	validation_0-mlogloss:0.64578
# [807]	validation_0-mlogloss:0.64578
# [808]	validation_0-mlogloss:0.64578
# [809]	validation_0-mlogloss:0.64578
# [810]	validation_0-mlogloss:0.64578
# [811]	validation_0-mlogloss:0.64578
# [812]	validation_0-mlogloss:0.64578
# [813]	validation_0-mlogloss:0.64578
# [814]	validation_0-mlogloss:0.64578
# [815]	validation_0-mlogloss:0.64577
# [816]	validation_0-mlogloss:0.64576
# [817]	validation_0-mlogloss:0.64576
# [818]	validation_0-mlogloss:0.64575
# [819]	validation_0-mlogloss:0.64575
# [820]	validation_0-mlogloss:0.64575
# [821]	validation_0-mlogloss:0.64575
# [822]	validation_0-mlogloss:0.64573
# [823]	validation_0-mlogloss:0.64573
# [824]	validation_0-mlogloss:0.64573
# [825]	validation_0-mlogloss:0.64572
# [826]	validation_0-mlogloss:0.64572
# [827]	validation_0-mlogloss:0.64572
# [828]	validation_0-mlogloss:0.64572
# [829]	validation_0-mlogloss:0.64571
# [830]	validation_0-mlogloss:0.64569
# [831]	validation_0-mlogloss:0.64569
# [832]	validation_0-mlogloss:0.64569
# [833]	validation_0-mlogloss:0.64569
# [834]	validation_0-mlogloss:0.64569
# [835]	validation_0-mlogloss:0.64569
# [836]	validation_0-mlogloss:0.64569
# [837]	validation_0-mlogloss:0.64569
# [838]	validation_0-mlogloss:0.64568
# [839]	validation_0-mlogloss:0.64568
# [840]	validation_0-mlogloss:0.64567
# [841]	validation_0-mlogloss:0.64567
# [842]	validation_0-mlogloss:0.64563
# [843]	validation_0-mlogloss:0.64563
# [844]	validation_0-mlogloss:0.64563
# [845]	validation_0-mlogloss:0.64563
# [846]	validation_0-mlogloss:0.64562
# [847]	validation_0-mlogloss:0.64562
# [848]	validation_0-mlogloss:0.64560
# [849]	validation_0-mlogloss:0.64559
# [850]	validation_0-mlogloss:0.64559
# [851]	validation_0-mlogloss:0.64559
# [852]	validation_0-mlogloss:0.64558
# [853]	validation_0-mlogloss:0.64556
# [854]	validation_0-mlogloss:0.64556
# [855]	validation_0-mlogloss:0.64556
# [856]	validation_0-mlogloss:0.64556
# [857]	validation_0-mlogloss:0.64555
# [858]	validation_0-mlogloss:0.64555
# [859]	validation_0-mlogloss:0.64555
# [860]	validation_0-mlogloss:0.64555
# [861]	validation_0-mlogloss:0.64554
# [862]	validation_0-mlogloss:0.64555
# [863]	validation_0-mlogloss:0.64555
# [864]	validation_0-mlogloss:0.64555
# [865]	validation_0-mlogloss:0.64555
# [866]	validation_0-mlogloss:0.64555
# [867]	validation_0-mlogloss:0.64553
# [868]	validation_0-mlogloss:0.64553
# [869]	validation_0-mlogloss:0.64553
# [870]	validation_0-mlogloss:0.64553
# [871]	validation_0-mlogloss:0.64553
# [872]	validation_0-mlogloss:0.64552
# [873]	validation_0-mlogloss:0.64551
# [874]	validation_0-mlogloss:0.64551
# [875]	validation_0-mlogloss:0.64551
# [876]	validation_0-mlogloss:0.64548
# [877]	validation_0-mlogloss:0.64548
# [878]	validation_0-mlogloss:0.64546
# [879]	validation_0-mlogloss:0.64545
# [880]	validation_0-mlogloss:0.64543
# [881]	validation_0-mlogloss:0.64543
# [882]	validation_0-mlogloss:0.64543
# [883]	validation_0-mlogloss:0.64544
# [884]	validation_0-mlogloss:0.64544
# [885]	validation_0-mlogloss:0.64544
# [886]	validation_0-mlogloss:0.64543
# [887]	validation_0-mlogloss:0.64543
# [888]	validation_0-mlogloss:0.64543
# [889]	validation_0-mlogloss:0.64542
# [890]	validation_0-mlogloss:0.64542
# [891]	validation_0-mlogloss:0.64539
# [892]	validation_0-mlogloss:0.64539
# [893]	validation_0-mlogloss:0.64539
# [894]	validation_0-mlogloss:0.64538
# [895]	validation_0-mlogloss:0.64538
# [896]	validation_0-mlogloss:0.64538
# [897]	validation_0-mlogloss:0.64537
# [898]	validation_0-mlogloss:0.64537
# [899]	validation_0-mlogloss:0.64536
# [900]	validation_0-mlogloss:0.64537
# [901]	validation_0-mlogloss:0.64536
# [902]	validation_0-mlogloss:0.64536
# [903]	validation_0-mlogloss:0.64536
# [904]	validation_0-mlogloss:0.64536
# [905]	validation_0-mlogloss:0.64536
# [906]	validation_0-mlogloss:0.64533
# [907]	validation_0-mlogloss:0.64533
# [908]	validation_0-mlogloss:0.64532
# [909]	validation_0-mlogloss:0.64532
# [910]	validation_0-mlogloss:0.64532
# [911]	validation_0-mlogloss:0.64530
# [912]	validation_0-mlogloss:0.64531
# [913]	validation_0-mlogloss:0.64521
# [914]	validation_0-mlogloss:0.64521
# [915]	validation_0-mlogloss:0.64521
# [916]	validation_0-mlogloss:0.64521
# [917]	validation_0-mlogloss:0.64520
# [918]	validation_0-mlogloss:0.64520
# [919]	validation_0-mlogloss:0.64520
# [920]	validation_0-mlogloss:0.64520
# [921]	validation_0-mlogloss:0.64520
# [922]	validation_0-mlogloss:0.64520
# [923]	validation_0-mlogloss:0.64519
# [924]	validation_0-mlogloss:0.64518
# [925]	validation_0-mlogloss:0.64518
# [926]	validation_0-mlogloss:0.64516
# [927]	validation_0-mlogloss:0.64516
# [928]	validation_0-mlogloss:0.64515
# [929]	validation_0-mlogloss:0.64515
# [930]	validation_0-mlogloss:0.64515
# [931]	validation_0-mlogloss:0.64515
# [932]	validation_0-mlogloss:0.64515
# [933]	validation_0-mlogloss:0.64514
# [934]	validation_0-mlogloss:0.64514
# [935]	validation_0-mlogloss:0.64514
# [936]	validation_0-mlogloss:0.64510
# [937]	validation_0-mlogloss:0.64510
# [938]	validation_0-mlogloss:0.64510
# [939]	validation_0-mlogloss:0.64498
# [940]	validation_0-mlogloss:0.64497
# [941]	validation_0-mlogloss:0.64497
# [942]	validation_0-mlogloss:0.64493
# [943]	validation_0-mlogloss:0.64493
# [944]	validation_0-mlogloss:0.64494
# [945]	validation_0-mlogloss:0.64494
# [946]	validation_0-mlogloss:0.64493
# [947]	validation_0-mlogloss:0.64493
# [948]	validation_0-mlogloss:0.64493
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_400/1063865443.py in <module>
#      14 y_val_pred = model.predict(X_valid_enc)
#      15 val_accuracy = accuracy_score(y_valid, y_val_pred)
# ---> 16 print(f"{model_name} Validation Accuracy: {val_accuracy:.4f}")
#      17 print(classification_report(y_valid, y_val_pred))
#      18
#
# NameError: name 'model_name' is not defined

# %%
y_val_pred = model.predict(X_valid_enc)
val_accuracy = accuracy_score(y_valid, y_val_pred)
print(f"Validation Accuracy: {val_accuracy:.4f}")
print(classification_report(y_valid, y_val_pred))

# Predict on the test set
y_test_pred = model.predict(X_test_enc)

# Evaluate the model on the test set
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Accuracy: {test_accuracy:.4f}")
print(classification_report(y_test, y_test_pred))
plot_confusion_matrix(y_test, y_test_pred, title='XGBoost Confusion Matrix (Test Set)')
# Out:
# Validation Accuracy: 0.7159
#               precision    recall  f1-score   support
#
#            0       0.31      0.00      0.01     19535
#            1       0.43      0.00      0.01     79346
#            2       0.73      0.93      0.82   3078482
#            3       0.62      0.28      0.39   1362903
#            4       0.13      0.00      0.00      6199
#
#     accuracy                           0.72   4546465
#    macro avg       0.44      0.24      0.24   4546465
# weighted avg       0.69      0.72      0.67   4546465
#
# Test Accuracy: 0.7161
#               precision    recall  f1-score   support
#
#            0       0.34      0.00      0.01     24419
#            1       0.44      0.00      0.01     99183
#            2       0.73      0.93      0.82   3848102
#            3       0.62      0.28      0.39   1703629
#            4       0.13      0.00      0.00      7748
#
#     accuracy                           0.72   5683081
#    macro avg       0.45      0.24      0.24   5683081
# weighted avg       0.69      0.72      0.67   5683081

# %%
with open('xgb_model_1.pkl', 'wb') as f:
    pickle.dump(model, f)
